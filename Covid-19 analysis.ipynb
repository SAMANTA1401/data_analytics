# %%
import pandas as pd

# %%
data = pd.read_csv("D:\datacsv\country_wise_latest.csv")

# %%
data.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
# data.isnull()

# %%
data.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
data.count()
# Out:
# Country/Region            187
# Confirmed                 187
# Deaths                    187
# Recovered                 187
# Active                    187
# New cases                 187
# New deaths                187
# New recovered             187
# Deaths / 100 Cases        187
# Recovered / 100 Cases     187
# Deaths / 100 Recovered    187
# Confirmed last week       187
# 1 week change             187
# 1 week % increase         187
# WHO Region                187
# dtype: int64

# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
sn.heatmap(data.isnull())
plt.show()

# %% [markdown]
# # 1.Show the number of \confirmed, Death and Recovered cases in each Region

# %%
data.head(3)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe
# ...

# %%
data.groupby('Country/Region')

# %%
data.groupby('Country/Region').sum().head(5)
# Out:
#                 Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# Country/Region
# Afghanistan         36263    1269      25198    9796        106          10
# Albania              4880     144       2745    1991        117           6
# Algeria             27973    1163      18837    7973        616           8
# Andorra               907      52        803      52         10           0
# Angola                950      41        242     667         18           1
#
#                 New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Country/Region
# Afghanistan                18                3.50                  69.49
# Albania                    63                2.95                  56.25
# Algeria                   749                4.16                  67.34
# Andorra                     0                5.73                  88.53
# Angola                      0                4.32                  25.47
#
# ...

# %%
data.groupby('Country/Region').Deaths

# %%
data.groupby('Country/Region').Deaths.sum()
# Out:
# Country/Region
# Afghanistan           1269
# Albania                144
# Algeria               1163
# Andorra                 52
# Angola                  41
#                       ...
# West Bank and Gaza      78
# Western Sahara           1
# Yemen                  483
# Zambia                 140
# Zimbabwe                36
# Name: Deaths, Length: 187, dtype: int64

# %%
plt.plot(data['Country/Region'],data['Deaths'])

# %%
data.groupby('Country/Region').Deaths.sum().sort_values(ascending=False)
# Out:
# Country/Region
# US                148011
# Brazil             87618
# United Kingdom     45844
# Mexico             44022
# Italy              35112
#                    ...
# Laos                   0
# Greenland              0
# Cambodia               0
# Grenada                0
# Mongolia               0
# Name: Deaths, Length: 187, dtype: int64

# %%
data.groupby('Country/Region').Confirmed.sum().sort_values(ascending=False)
# Out:
# Country/Region
# US                       4290259
# Brazil                   2442375
# India                    1480073
# Russia                    816680
# South Africa              452529
#                           ...
# Dominica                      18
# Saint Kitts and Nevis         17
# Greenland                     14
# Holy See                      12
# Western Sahara                10
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Country/Region')['Deaths','Confirmed','Recovered'].sum()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6456\589842607.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Country/Region')['Deaths','Confirmed','Recovered'].sum()
#                     Deaths  Confirmed  Recovered
# Country/Region
# Afghanistan           1269      36263      25198
# Albania                144       4880       2745
# Algeria               1163      27973      18837
# Andorra                 52        907        803
# Angola                  41        950        242
# ...                    ...        ...        ...
# West Bank and Gaza      78      10621       3752
# Western Sahara           1         10          8
# Yemen                  483       1691        833
# Zambia                 140       4552       2815
# Zimbabwe                36       2704        542
#
# [187 rows x 3 columns]

# %% [markdown]
# # Q2.Remove all the records where Confirmed Cases is Less than 10

# %%
data.head(3)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe
# ...

# %%
data[data['Confirmed']<10]
# Out:
# Empty DataFrame
# Columns: [Country/Region, Confirmed, Deaths, Recovered, Active, New cases, New deaths, New recovered, Deaths / 100 Cases, Recovered / 100 Cases, Deaths / 100 Recovered, Confirmed last week, 1 week change, 1 week % increase, WHO Region]
# Index: []

# %%
data[data['Deaths']<10].head(5)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 5   Antigua and Barbuda         86       3         65      18          4
# 14             Barbados        110       7         94       9          0
# 17               Belize         48       2         26      20          0
# 19               Bhutan         99       0         86      13          4
# 22             Botswana        739       2         63     674         53
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 5            0              5                3.49                  75.58
# 14           0              0                6.36                  85.45
# 17           0              0                4.17                  54.17
# 19           0              1                0.00                  86.87
# 22           1             11                0.27                   8.53
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
data.Confirmed<10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# Name: Confirmed, Length: 187, dtype: bool

# %%
data = data[~data['Confirmed']<10]

# %%
data.head(7)
# Out:
#         Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0          Afghanistan      36263    1269      25198    9796        106
# 1              Albania       4880     144       2745    1991        117
# 2              Algeria      27973    1163      18837    7973        616
# 3              Andorra        907      52        803      52         10
# 4               Angola        950      41        242     667         18
# 5  Antigua and Barbuda         86       3         65      18          4
# 6            Argentina     167416    3059      72575   91782       4890
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0          10             18                3.50                  69.49
# 1           6             63                2.95                  56.25
# 2           8            749                4.16                  67.34
# 3           0              0                5.73                  88.53
# ...

# %% [markdown]
# # Q3.In which region ,maximum number of Confirmed cases were recorded?

# %%
data.groupby('Country/Region').Confirmed.max()
# Out:
# Country/Region
# Afghanistan           36263
# Albania                4880
# Algeria               27973
# Andorra                 907
# Angola                  950
#                       ...
# West Bank and Gaza    10621
# Western Sahara           10
# Yemen                  1691
# Zambia                 4552
# Zimbabwe               2704
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Country/Region').Confirmed.sum()
# Out:
# Country/Region
# Afghanistan           36263
# Albania                4880
# Algeria               27973
# Andorra                 907
# Angola                  950
#                       ...
# West Bank and Gaza    10621
# Western Sahara           10
# Yemen                  1691
# Zambia                 4552
# Zimbabwe               2704
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Country/Region').Confirmed.sum().sort_values(ascending=False)
# Out:
# Country/Region
# US                       4290259
# Brazil                   2442375
# India                    1480073
# Russia                    816680
# South Africa              452529
#                           ...
# Dominica                      18
# Saint Kitts and Nevis         17
# Greenland                     14
# Holy See                      12
# Western Sahara                10
# Name: Confirmed, Length: 187, dtype: int64

# %% [markdown]
# # q4.in which region ,minimum number of Deaths cases were recorded?

# %%
data.groupby('Country/Region').Deaths.sum().sort_values(ascending=True)
# Out:
# Country/Region
# Fiji                   0
# Holy See               0
# Grenada                0
# Laos                   0
# Greenland              0
#                    ...
# Italy              35112
# Mexico             44022
# United Kingdom     45844
# Brazil             87618
# US                148011
# Name: Deaths, Length: 187, dtype: int64

# %% [markdown]
# # Q5.How many Confirmed ,Deaths and Recovered cases were reported in india from till 29 April 2020?

# %%
data[data['Country/Region']== 'India']
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 79          India    1480073   33408     951166  495499      44457
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 79         637          33598                2.26                  64.26
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 79                    3.51              1155338         324735
#
#     1 week % increase       WHO Region
# 79              28.11  South-East Asia

# %% [markdown]
# # Q6.Sort the entire data wrt No.of recovered cases in ascending order?

# %%
data.sort_values(by=['Confirmed'], ascending=True)
# Out:
#             Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 183         Western Sahara         10       1          8        1          0
# 75                Holy See         12       0         12        0          0
# 68               Greenland         14       0         13        1          1
# 140  Saint Kitts and Nevis         17       0         15        2          0
# 49                Dominica         18       0         18        0          0
# ..                     ...        ...     ...        ...      ...        ...
# 154           South Africa     452529    7067     274925   170537       7096
# 138                 Russia     816680   13334     602249   201097       5607
# 79                   India    1480073   33408     951166   495499      44457
# 23                  Brazil    2442375   87618    1846641   508116      23284
# 173                     US    4290259  148011    1325804  2816444      56336
#
# ...

# %%
data.sort_values(by=['Deaths'], ascending=False)
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 177  United Kingdom     301708   45844       1437   254427        688
# 111          Mexico     395489   44022     303810    47657       4973
# 85            Italy     246286   35112     198593    12581        168
# ..              ...        ...     ...        ...      ...        ...
# 94             Laos         20       0         19        1          0
# 68        Greenland         14       0         13        1          1
# 30         Cambodia        226       0        147       79          1
# 69          Grenada         23       0         23        0          0
# 114        Mongolia        289       0        222       67          1
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...
