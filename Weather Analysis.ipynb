# %% [markdown]
# # the weather Dataset

# %% [markdown]
# -unique() and unique
# -value_counts
# -filtering
# -groupby
# -getgroup
# -isnull() and notnull
# -rename
# -mean
# -std
# -var
# -str.contains
# -and operator
# -or operator
# -min and max

# %% [markdown]
# the weather dataset is a timeseries dataset with per hours information about the weather conditions at a particular location . it records tempetature ,dew point , relative humidity, wind speed , visiblity , pressure , and conditions

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("D:\cars\datascience project\weatherHistory.csv")

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
data[50:100]
# Out:
#                    Formatted Date                   Summary Precip Type  \
# 50  2006-04-11 02:00:00.000 +0200                  Overcast        rain
# 51  2006-04-11 03:00:00.000 +0200                  Overcast        rain
# 52  2006-04-11 04:00:00.000 +0200                  Overcast        rain
# 53  2006-04-11 05:00:00.000 +0200                  Overcast        rain
# 54  2006-04-11 06:00:00.000 +0200             Mostly Cloudy        rain
# 55  2006-04-11 07:00:00.000 +0200             Mostly Cloudy        rain
# 56  2006-04-11 08:00:00.000 +0200             Partly Cloudy        rain
# 57  2006-04-11 09:00:00.000 +0200             Partly Cloudy        rain
# 58  2006-04-11 10:00:00.000 +0200             Partly Cloudy        rain
# 59  2006-04-11 11:00:00.000 +0200             Partly Cloudy        rain
# 60  2006-04-11 12:00:00.000 +0200             Mostly Cloudy        rain
# 61  2006-04-11 13:00:00.000 +0200             Mostly Cloudy        rain
# ...

# %%
data.loc[50:100]
# Out:
#                     Formatted Date                   Summary Precip Type  \
# 50   2006-04-11 02:00:00.000 +0200                  Overcast        rain
# 51   2006-04-11 03:00:00.000 +0200                  Overcast        rain
# 52   2006-04-11 04:00:00.000 +0200                  Overcast        rain
# 53   2006-04-11 05:00:00.000 +0200                  Overcast        rain
# 54   2006-04-11 06:00:00.000 +0200             Mostly Cloudy        rain
# 55   2006-04-11 07:00:00.000 +0200             Mostly Cloudy        rain
# 56   2006-04-11 08:00:00.000 +0200             Partly Cloudy        rain
# 57   2006-04-11 09:00:00.000 +0200             Partly Cloudy        rain
# 58   2006-04-11 10:00:00.000 +0200             Partly Cloudy        rain
# 59   2006-04-11 11:00:00.000 +0200             Partly Cloudy        rain
# 60   2006-04-11 12:00:00.000 +0200             Mostly Cloudy        rain
# 61   2006-04-11 13:00:00.000 +0200             Mostly Cloudy        rain
# ...

# %%
data.iloc[50:100]
# Out:
#                    Formatted Date                   Summary Precip Type  \
# 50  2006-04-11 02:00:00.000 +0200                  Overcast        rain
# 51  2006-04-11 03:00:00.000 +0200                  Overcast        rain
# 52  2006-04-11 04:00:00.000 +0200                  Overcast        rain
# 53  2006-04-11 05:00:00.000 +0200                  Overcast        rain
# 54  2006-04-11 06:00:00.000 +0200             Mostly Cloudy        rain
# 55  2006-04-11 07:00:00.000 +0200             Mostly Cloudy        rain
# 56  2006-04-11 08:00:00.000 +0200             Partly Cloudy        rain
# 57  2006-04-11 09:00:00.000 +0200             Partly Cloudy        rain
# 58  2006-04-11 10:00:00.000 +0200             Partly Cloudy        rain
# 59  2006-04-11 11:00:00.000 +0200             Partly Cloudy        rain
# 60  2006-04-11 12:00:00.000 +0200             Mostly Cloudy        rain
# 61  2006-04-11 13:00:00.000 +0200             Mostly Cloudy        rain
# ...

# %%
data.tail()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# ...

# %% [markdown]
# # How to anslyze dataframe?

# %%
data.shape
# Out:
# (96453, 12)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=96453, step=1)

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
# -unique(): in a column it shows  all the unique values .it can be applied on a single columns only. not on the whole dataframe

# %%
data.Summary.unique()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %%
data['Summary'].unique()
# Out:
# array(['Partly Cloudy', 'Mostly Cloudy', 'Overcast', 'Foggy',
#        'Breezy and Mostly Cloudy', 'Clear', 'Breezy and Partly Cloudy',
#        'Breezy and Overcast', 'Humid and Mostly Cloudy',
#        'Humid and Partly Cloudy', 'Windy and Foggy', 'Windy and Overcast',
#        'Breezy and Foggy', 'Windy and Partly Cloudy', 'Breezy',
#        'Dry and Partly Cloudy', 'Windy and Mostly Cloudy',
#        'Dangerously Windy and Partly Cloudy', 'Dry', 'Windy',
#        'Humid and Overcast', 'Light Rain', 'Drizzle', 'Windy and Dry',
#        'Dry and Mostly Cloudy', 'Breezy and Dry', 'Rain'], dtype=object)

# %%
# -nunique(): it shows the total no of unique values in each column it can be applied on a single columns as well as on whole dataframe

# %%
data.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %%
data.Summary.nunique()
# Out:
# 27

# %%
# -count: it shows the total no of non-null in each columns . it can be applied on a single columns as well as on whole dataframe

# %%
data.count()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %%
data.Summary.count()
# Out:
# 96453

# %%
# -value_counts:in a columns it shows all ther unique values with their count. it can be applied on single column only

# %%
data.value_counts
# Out:
# <bound method DataFrame.value_counts of                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
data[96400:]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96400  2016-09-07 19:00:00.000 +0200  Partly Cloudy        rain
# 96401  2016-09-07 20:00:00.000 +0200  Partly Cloudy        rain
# 96402  2016-09-07 21:00:00.000 +0200  Partly Cloudy        rain
# 96403  2016-09-07 22:00:00.000 +0200  Partly Cloudy        rain
# 96404  2016-09-07 23:00:00.000 +0200  Partly Cloudy        rain
# 96405  2016-09-08 00:00:00.000 +0200          Clear        rain
# 96406  2016-09-08 01:00:00.000 +0200  Partly Cloudy        rain
# 96407  2016-09-08 02:00:00.000 +0200  Partly Cloudy        rain
# 96408  2016-09-08 03:00:00.000 +0200  Partly Cloudy        rain
# 96409  2016-09-08 04:00:00.000 +0200  Partly Cloudy        rain
# 96410  2016-09-08 05:00:00.000 +0200  Mostly Cloudy        rain
# 96411  2016-09-08 06:00:00.000 +0200  Mostly Cloudy        rain
# 96412  2016-09-08 07:00:00.000 +0200  Mostly Cloudy        rain
# 96413  2016-09-08 08:00:00.000 +0200  Mostly Cloudy        rain
# ...

# %%
data[500:550].count()
# Out:
# Formatted Date              50
# Summary                     50
# Precip Type                 50
# Temperature (C)             50
# Apparent Temperature (C)    50
# Humidity                    50
# Wind Speed (km/h)           50
# Wind Bearing (degrees)      50
# Visibility (km)             50
# Loud Cover                  50
# Pressure (millibars)        50
# Daily Summary               50
# dtype: int64

# %%
data.Summary.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Partly Cloudy
# 1        Partly Cloudy
# 2        Mostly Cloudy
# 3        Partly Cloudy
# 4        Mostly Cloudy
#              ...
# 96448    Partly Cloudy
# 96449    Partly Cloudy
# 96450    Partly Cloudy
# 96451    Partly Cloudy
# 96452    Partly Cloudy
# Name: Summary, Length: 96453, dtype: object>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
data.info
# Out:
# <bound method DataFrame.info of                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %% [markdown]
# # Q1.Find all the unique 'Wind Speed' values in the data.

# %%
data['Wind Speed (km/h)'].unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %%
data['Wind Speed (km/h)']
# Out:
# 0        14.1197
# 1        14.2646
# 2         3.9284
# 3        14.1036
# 4        11.0446
#           ...
# 96448    10.9963
# 96449    10.0947
# 96450     8.9838
# 96451    10.5294
# 96452     5.8765
# Name: Wind Speed (km/h), Length: 96453, dtype: float64

# %%
data['Wind Speed (km/h)'][100:150]
# Out:
# 100    20.5275
# 101    19.3039
# 102    17.4363
# 103    20.4148
# 104    17.0499
# 105    20.5114
# 106    17.6456
# 107    14.4095
# 108    10.7548
# 109     4.8622
# 110     2.3828
# 111     0.3220
# 112     3.2522
# 113     3.0107
# 114    10.4650
# 115     7.3416
# 116     9.5151
# 117     9.9981
# 118    13.6850
# 119    11.5437
# 120    12.7190
# 121    12.8961
# 122     0.6923
# 123     5.5384
# 124     5.2003
# 125     5.6189
# 126     4.7656
# 127     7.9212
# 128     9.7566
# 129     9.6922
# 130    14.4900
# 131    20.3343
# 132    23.5865
# 133    22.2985
# 134    14.7154
# 135    14.4900
# 136    14.7154
# 137    19.5937
# 138    14.8281
# 139    11.9784
# 140    11.5598
# 141    14.2485
# 142    11.2539
# 143     5.7799
# 144     2.6404
# 145     5.3130
# 146    11.3827
# 147     3.6547
# 148    10.8675
# 149     6.5205
# Name: Wind Speed (km/h), dtype: float64

# %%
data.nunique()
# Out:
# Formatted Date              96429
# Summary                        27
# Precip Type                     2
# Temperature (C)              7574
# Apparent Temperature (C)     8984
# Humidity                       90
# Wind Speed (km/h)            2484
# Wind Bearing (degrees)        360
# Visibility (km)               949
# Loud Cover                      1
# Pressure (millibars)         4979
# Daily Summary                 214
# dtype: int64

# %%
data['Wind Speed (km/h)'].nunique()
# Out:
# 2484

# %% [markdown]
# # Q2. Find the number of times when the 'weather is exactly Clear'.

# %%
data[data['Summary']=='Clear']
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
data[data.Summary=='Clear']
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
data[data['Summary']=='Clear'].count()
# Out:
# Formatted Date              10890
# Summary                     10890
# Precip Type                 10763
# Temperature (C)             10890
# Apparent Temperature (C)    10890
# Humidity                    10890
# Wind Speed (km/h)           10890
# Wind Bearing (degrees)      10890
# Visibility (km)             10890
# Loud Cover                  10890
# Pressure (millibars)        10890
# Daily Summary               10890
# dtype: int64

# %%
data[data['Summary']=='Clear'].value_counts()
# Out:
# Formatted Date                 Summary  Precip Type  Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  Daily Summary
# 2010-08-02 05:00:00.000 +0200  Clear    rain         15.955556        15.955556                 0.99      3.8801             276.0                   9.9820           0.0         1016.69               Partly cloudy starting in the afternoon continuing until evening.    2
# 2010-08-02 20:00:00.000 +0200  Clear    rain         25.250000        25.250000                 0.75      2.4955             335.0                   10.3523          0.0         1013.20               Partly cloudy starting in the afternoon continuing until evening.    2
# ...

# %%
data.Summary.value_counts()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
#filter
data.Summary =='Clear'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 96448    False
# 96449    False
# 96450    False
# 96451    False
# 96452    False
# Name: Summary, Length: 96453, dtype: bool

# %%
#groupby
data.groupby('Summary').get_group('Clear')
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
data[data['Wind Speed (km/h)']>4]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# 5      2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
data[data['Wind Speed (km/h)']==4]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %% [markdown]
# # Q4.Find out all ther Null values in the data

# %%
data.isnull()
# Out:
#        Formatted Date  Summary  Precip Type  Temperature (C)  \
# 0               False    False        False            False
# 1               False    False        False            False
# 2               False    False        False            False
# 3               False    False        False            False
# 4               False    False        False            False
# ...               ...      ...          ...              ...
# 96448           False    False        False            False
# 96449           False    False        False            False
# 96450           False    False        False            False
# 96451           False    False        False            False
# 96452           False    False        False            False
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                         False     False              False
# 1                         False     False              False
# ...

# %%
data.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Formatted Date              96453
# Summary                     96453
# Precip Type                 95936
# Temperature (C)             96453
# Apparent Temperature (C)    96453
# Humidity                    96453
# Wind Speed (km/h)           96453
# Wind Bearing (degrees)      96453
# Visibility (km)             96453
# Loud Cover                  96453
# Pressure (millibars)        96453
# Daily Summary               96453
# dtype: int64

# %% [markdown]
# # Q4.Rrname the column name 'Weather' of the dataframe to 'Weather Condition'

# %%
data.rename(columns={'Summary':'Weather Condition'})
# Out:
#                       Formatted Date Weather Condition Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200     Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200     Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200     Mostly Cloudy        rain
# ...                              ...               ...         ...
# 96448  2016-09-09 19:00:00.000 +0200     Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200     Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200     Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200     Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200     Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %% [markdown]
# # Q5.what is the mean 'Visibility'?

# %%
data.head(2)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
data['Visibility (km)'].mean()
# Out:
# 10.347324929237148

# %%
# data.Visibility (km).mean()

# %% [markdown]
# # Q6.What is the Standard Deviation of 'Pressure' in this data?

# %%
data['Pressure (millibars)'].std()
# Out:
# 116.96990568258147

# %% [markdown]
# # Q7.What is the Variance of 'Realtive Humidity' in  this data?

# %%
data['Humidity'].var()
# Out:
# 0.03820959171844407

# %% [markdown]
# # Q8.Find all instances when 'Snow' was recorded

# %%
data['Summary'].value_counts()
# Out:
# Partly Cloudy                          31733
# Mostly Cloudy                          28094
# Overcast                               16597
# Clear                                  10890
# Foggy                                   7148
# Breezy and Overcast                      528
# Breezy and Mostly Cloudy                 516
# Breezy and Partly Cloudy                 386
# Dry and Partly Cloudy                     86
# Windy and Partly Cloudy                   67
# Light Rain                                63
# Breezy                                    54
# Windy and Overcast                        45
# Humid and Mostly Cloudy                   40
# Drizzle                                   39
# Breezy and Foggy                          35
# Windy and Mostly Cloudy                   35
# Dry                                       34
# Humid and Partly Cloudy                   17
# Dry and Mostly Cloudy                     14
# Rain                                      10
# ...

# %%
data[data['Summary']=='Snow']
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
#str.contains
data[data['Summary'].str.contains('Snow')]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %% [markdown]
# # Q9.Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'

# %%
data[(data['Wind Speed (km/h)']>24) & (data['Visibility (km)']>25)]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
data[(data['Wind Speed (km/h)']<3) & (data['Visibility (km)']>15)]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 122    2006-04-14 02:00:00.000 +0200  Partly Cloudy        rain
# 144    2006-04-15 00:00:00.000 +0200  Mostly Cloudy        rain
# 358    2006-04-22 22:00:00.000 +0200          Clear        rain
# 382    2006-04-23 22:00:00.000 +0200  Partly Cloudy        rain
# 888    2006-08-16 00:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 96403  2016-09-07 22:00:00.000 +0200  Partly Cloudy        rain
# 96407  2016-09-08 02:00:00.000 +0200  Partly Cloudy        rain
# 96424  2016-09-08 19:00:00.000 +0200  Partly Cloudy        rain
# 96429  2016-09-09 00:00:00.000 +0200  Partly Cloudy        rain
# 96436  2016-09-09 07:00:00.000 +0200          Clear        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 122           8.338889                  8.338889      0.88             0.6923
# ...

# %% [markdown]
# # Q10.What is the Mean value of each column against each 'Weather Condition'?

# %%
data.groupby('Summary').mean()
# Out:
#                                      Temperature (C)  \
# Summary
# Breezy                                      7.922016
# Breezy and Dry                             21.111111
# Breezy and Foggy                           -0.510317
# Breezy and Mostly Cloudy                   11.093411
# Breezy and Overcast                         7.241614
# Breezy and Partly Cloudy                   12.492761
# Clear                                      11.925109
# Dangerously Windy and Partly Cloudy         8.944444
# Drizzle                                    10.847578
# Dry                                        29.083660
# Dry and Mostly Cloudy                      26.838492
# Dry and Partly Cloudy                      26.605749
# Foggy                                       1.464035
# Humid and Mostly Cloudy                    20.886389
# Humid and Overcast                         21.515079
# Humid and Partly Cloudy                    21.568301
# ...

# %% [markdown]
# # Q11.What is the minimum and maximum value of each column against each 'Weather Condition'?

# %%
data.groupby('Summary').min()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7372\18306074.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   data.groupby('Summary').min()
#                                                     Formatted Date  \
# Summary
# Breezy                               2006-09-17 12:00:00.000 +0200
# Breezy and Dry                       2012-03-18 11:00:00.000 +0100
# Breezy and Foggy                     2006-03-13 07:00:00.000 +0100
# Breezy and Mostly Cloudy             2006-01-22 17:00:00.000 +0100
# Breezy and Overcast                  2006-01-19 09:00:00.000 +0100
# Breezy and Partly Cloudy             2006-03-25 08:00:00.000 +0100
# Clear                                2006-01-08 01:00:00.000 +0100
# Dangerously Windy and Partly Cloudy  2007-01-29 13:00:00.000 +0100
# ...

# %%
data.groupby('Summary').max()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_7372\1425479235.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   data.groupby('Summary').max()
#                                                     Formatted Date  \
# Summary
# Breezy                               2016-08-05 10:00:00.000 +0200
# Breezy and Dry                       2012-03-18 11:00:00.000 +0100
# Breezy and Foggy                     2015-02-08 17:00:00.000 +0100
# Breezy and Mostly Cloudy             2016-09-17 15:00:00.000 +0200
# Breezy and Overcast                  2016-10-04 23:00:00.000 +0200
# Breezy and Partly Cloudy             2016-08-10 19:00:00.000 +0200
# Clear                                2016-11-02 23:00:00.000 +0100
# Dangerously Windy and Partly Cloudy  2007-01-29 13:00:00.000 +0100
# ...

# %% [markdown]
# # Q12.Show all the Records where Weather Condition is Fog.

# %%
data[data['Summary']=='Foggy']
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 66     2006-04-11 18:00:00.000 +0200   Foggy        rain        10.911111
# 67     2006-04-11 19:00:00.000 +0200   Foggy        rain         8.800000
# 72     2006-04-12 00:00:00.000 +0200   Foggy        rain         8.200000
# 73     2006-04-12 01:00:00.000 +0200   Foggy        rain         8.177778
# 126    2006-04-14 06:00:00.000 +0200   Foggy        rain         5.211111
# ...                              ...     ...         ...              ...
# 95858  2016-09-14 05:00:00.000 +0200   Foggy        rain        13.144444
# 95859  2016-09-14 06:00:00.000 +0200   Foggy        rain        13.822222
# 95860  2016-09-14 07:00:00.000 +0200   Foggy        rain        13.872222
# 95907  2016-09-16 06:00:00.000 +0200   Foggy        rain        14.905556
# 96228  2016-09-28 15:00:00.000 +0200   Foggy        rain        22.800000
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
data.groupby('Summary').get_group('Foggy')
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 66     2006-04-11 18:00:00.000 +0200   Foggy        rain        10.911111
# 67     2006-04-11 19:00:00.000 +0200   Foggy        rain         8.800000
# 72     2006-04-12 00:00:00.000 +0200   Foggy        rain         8.200000
# 73     2006-04-12 01:00:00.000 +0200   Foggy        rain         8.177778
# 126    2006-04-14 06:00:00.000 +0200   Foggy        rain         5.211111
# ...                              ...     ...         ...              ...
# 95858  2016-09-14 05:00:00.000 +0200   Foggy        rain        13.144444
# 95859  2016-09-14 06:00:00.000 +0200   Foggy        rain        13.822222
# 95860  2016-09-14 07:00:00.000 +0200   Foggy        rain        13.872222
# 95907  2016-09-16 06:00:00.000 +0200   Foggy        rain        14.905556
# 96228  2016-09-28 15:00:00.000 +0200   Foggy        rain        22.800000
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %% [markdown]
# # Q13.Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
data[(data['Summary']=='Clear') & (data['Visibility (km)']>4)]
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# 358    2006-04-22 22:00:00.000 +0200   Clear        rain        12.244444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
data[(data['Summary']=='Clear') & (data['Visibility (km)']>4)|(data['Visibility (km)']>4)]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...
