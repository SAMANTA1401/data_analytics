# %%
import pandas as pd
import numpy as np

# %%
dict1 = {
    "name":['harry','rohan','skillf','subha'],
    "marks":[67,89,23,56],
    "city":['rampur','kolkata','antartika','usa']
    
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks       city
# 0   harry     67     rampur
# 1   rohan     89    kolkata
# 2  skillf     23  antartika
# 3   subha     56        usa

# %%
df.to_csv('freinds.csv')

# %%
df.to_csv('freinds1.csv', index=False)

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  harry     67   rampur
# 1  rohan     89  kolkata

# %%
df.tail(2)
# Out:
#      name  marks       city
# 2  skillf     23  antartika
# 3   subha     56        usa

# %%
df.describe()
# Out:
#        marks
# count   4.00
# mean   58.75
# std    27.50
# min    23.00
# 25%    47.75
# 50%    61.50
# 75%    72.50
# max    89.00

# %%
harry = pd.read_csv('D:/cars/train_speed.csv')

# %%
harry
# Out:
#    Train No  Speed       City
# 0     32567     45     raipur
# 1     15676     34    kolkata
# 2     13567     67      delhi
# 3     15463     54  bangalore

# %%
harry['Speed']
# Out:
# 0    45
# 1    34
# 2    67
# 3    54
# Name: Speed, dtype: int64

# %%
harry['Speed'][0]
# Out:
# 45

# %%
harry['Speed'][0]=50
# Out:
# C:\Users\lenovo\AppData\Local\Temp/ipykernel_15572/957813252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   harry['Speed'][0]=50

# %%
harry['Speed'][0]
# Out:
# 50

# %%
harry
# Out:
#    Train No  Speed       City
# 0     32567     50     raipur
# 1     15676     34    kolkata
# 2     13567     67      delhi
# 3     15463     54  bangalore

# %%
#to create csv file
harry.to_csv('harry.csv')

# %%
# to add row name
harry.index = ['first','second','third','fourth']

# %%
harry
# Out:
#         Train No  Speed       City
# first      32567     50     raipur
# second     15676     34    kolkata
# third      13567     67      delhi
# fourth     15463     54  bangalore

# %%
# pandas has two type of data type 1.series 2.dataframe
ser = pd.Series(np.random.rand)

# %%
ser
# Out:
# 0    <built-in method rand of numpy.random.mtrand.R...
# dtype: object

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.860804
# 1     0.296054
# 2     0.281409
# 3     0.299848
# 4     0.511504
# 5     0.144306
# 6     0.174339
# 7     0.039379
# 8     0.535605
# 9     0.320302
# 10    0.088379
# 11    0.972003
# 12    0.007426
# 13    0.811036
# 14    0.416149
# 15    0.150491
# 16    0.329088
# 17    0.983603
# 18    0.875569
# 19    0.034275
# 20    0.928571
# 21    0.031388
# 22    0.687593
# 23    0.942152
# 24    0.084804
# 25    0.480471
# 26    0.961906
# 27    0.848953
# 28    0.357072
# 29    0.222682
# 30    0.425260
# 31    0.946504
# 32    0.914117
# 33    0.077968
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
#index use for row
newdf = pd.DataFrame(np.random.rand(334,5), index = np.arange(334))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.041552  0.902834  0.266814  0.615113  0.658248
# 1  0.302846  0.463401  0.160703  0.993730  0.515828
# 2  0.680728  0.646071  0.544384  0.557151  0.408557
# 3  0.393464  0.522948  0.326698  0.748520  0.662080
# 4  0.599455  0.026758  0.227557  0.752740  0.915123

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.507344    0.512249    0.514700    0.473151    0.514835
# std      0.286179    0.298724    0.279169    0.294195    0.290224
# min      0.002377    0.001150    0.000926    0.001145    0.000678
# 25%      0.251389    0.256044    0.272936    0.200678    0.273484
# 50%      0.498405    0.527828    0.530159    0.459266    0.525736
# 75%      0.777751    0.768907    0.760656    0.724512    0.775749
# max      0.996248    0.999845    0.998449    0.993730    0.998802

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf[0][0]="harry"

# %%
newdf
# Out:
#             0         1         2         3         4
# 0
aN
#
# [334 rows x 6 columns]

# %%
newdf.loc[0,'B'] = 666

# %%
newdf
# Out:
#             A           B         C         D         E      0
# 0         999  666.000000  0.266814  0.615113  0.658248  333.0
# 1    0.302846    0.463401  0.160703  0.993730  0.515828    NaN
# 2    0.680728    0.646071  0.544384  0.557151  0.408557    NaN
# 3    0.393464    0.522948  0.326698  0.748520  0.662080    NaN
# 4    0.599455    0.026758  0.227557  0.752740  0.915123    NaN
# ..        ...         ...       ...       ...       ...    ...
# 329  0.472912    0.255756  0.264073  0.348511  0.193227    NaN
# 330  0.536868    0.999761  0.165711  0.231258  0.125143    NaN
# 331  0.916344    0.598993  0.884324  0.001173  0.369801    NaN
# 332  0.200755    0.498294  0.884382  0.790672  0.959268    NaN
# 333  0.445882    0.026390  0.683923  0.375473  0.663276    NaN
#
# [334 rows x 6 columns]

# %%
#to delete 0 column but not in original newdf only from copy
newdf.drop(0, axis=1)
# Out:
#             A           B         C         D         E
# 0         999  666.000000  0.266814  0.615113  0.658248
# 1    0.302846    0.463401  0.160703  0.993730  0.515828
# 2    0.680728    0.646071  0.544384  0.557151  0.408557
# 3    0.393464    0.522948  0.326698  0.748520  0.662080
# 4    0.599455    0.026758  0.227557  0.752740  0.915123
# ..        ...         ...       ...       ...       ...
# 329  0.472912    0.255756  0.264073  0.348511  0.193227
# 330  0.536868    0.999761  0.165711  0.231258  0.125143
# 331  0.916344    0.598993  0.884324  0.001173  0.369801
# 332  0.200755    0.498294  0.884382  0.790672  0.959268
# 333  0.445882    0.026390  0.683923  0.375473  0.663276
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           A           B         C         D         E      0
# 0       999  666.000000  0.266814  0.615113  0.658248  333.0
# 1  0.302846    0.463401  0.160703  0.993730  0.515828    NaN
# 2  0.680728    0.646071  0.544384  0.557151  0.408557    NaN
# 3  0.393464    0.522948  0.326698  0.748520  0.662080    NaN
# 4  0.599455    0.026758  0.227557  0.752740  0.915123    NaN

# %%
#assigne as newdf to drop in original newdf
newdf = newdf.drop(0, axis=1)

# %%
newdf
# Out:
#             A           B         C         D         E
# 0         999  666.000000  0.266814  0.615113  0.658248
# 1    0.302846    0.463401  0.160703  0.993730  0.515828
# 2    0.680728    0.646071  0.544384  0.557151  0.408557
# 3    0.393464    0.522948  0.326698  0.748520  0.662080
# 4    0.599455    0.026758  0.227557  0.752740  0.915123
# ..        ...         ...       ...       ...       ...
# 329  0.472912    0.255756  0.264073  0.348511  0.193227
# 330  0.536868    0.999761  0.165711  0.231258  0.125143
# 331  0.916344    0.598993  0.884324  0.001173  0.369801
# 332  0.200755    0.498294  0.884382  0.790672  0.959268
# 333  0.445882    0.026390  0.683923  0.375473  0.663276
#
# [334 rows x 5 columns]

# %%
#to return new dfataframe from this newdf
newdf.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0
# 331  0.916344  0.598993  0.884324  0.001173  0.369801
# 332  0.200755  0.498294  0.884382  0.790672  0.959268
# 333  0.445882  0.026390  0.683923  0.375473  0.663276
#
# [333 rows x 5 columns]

# %%
newdf
# Out:
#             A           B         C         D         E
# 0         999  666.000000  0.266814  0.615113  0.658248
# 1    0.302846    0.463401  0.160703  0.993730  0.515828
# 2    0.680728    0.646071  0.544384  0.557151  0.408557
# 3    0.393464    0.522948  0.326698  0.748520  0.662080
# 4    0.599455    0.026758  0.227557  0.752740  0.915123
# ..        ...         ...       ...       ...       ...
# 329  0.472912    0.255756  0.264073  0.348511  0.193227
# 330  0.536868    0.999761  0.165711  0.231258  0.125143
# 331  0.916344    0.598993  0.884324  0.001173  0.369801
# 332  0.200755    0.498294  0.884382  0.790672  0.959268
# 333  0.445882    0.026390  0.683923  0.375473  0.663276
#
# [334 rows x 5 columns]

# %%
newdf.drop(0)
# Out:
#             A         B         C         D         E
# 1    0.302846  0.463401  0.160703  0.993730  0.515828
# 2    0.680728  0.646071  0.544384  0.557151  0.408557
# 3    0.393464  0.522948  0.326698  0.748520  0.662080
# 4    0.599455  0.026758  0.227557  0.752740  0.915123
# 5    0.543507  0.317493  0.148108  0.366458  0.286330
# ..        ...       ...       ...       ...       ...
# 329  0.472912  0.255756  0.264073  0.348511  0.193227
# 330  0.536868  0.999761  0.165711  0.231258  0.125143
# 331  0.916344  0.598993  0.884324  0.001173  0.369801
# 332  0.200755  0.498294  0.884382  0.790672  0.959268
# 333  0.445882  0.026390  0.683923  0.375473  0.663276
#
# [333 rows x 5 columns]

# %%
# only change in copy of newdf
newdf.drop(['C','D'], axis=1)
# Out:
#             A           B         E
# 0         999  666.000000  0.658248
# 1    0.302846    0.463401  0.515828
# 2    0.680728    0.646071  0.408557
# 3    0.393464    0.522948  0.662080
# 4    0.599455    0.026758  0.915123
# ..        ...         ...       ...
# 329  0.472912    0.255756  0.193227
# 330  0.536868    0.999761  0.125143
# 331  0.916344    0.598993  0.369801
# 332  0.200755    0.498294  0.959268
# 333  0.445882    0.026390  0.663276
#
# [334 rows x 3 columns]

# %%
# to change in original newdf inplace=True
newdf.drop(['B','C'], axis=1, inplace=True)

# %%
newdf
# Out:
#             A         D         E
# 0         999  0.615113  0.658248
# 1    0.302846  0.993730  0.515828
# 2    0.680728  0.557151  0.408557
# 3    0.393464  0.748520  0.662080
# 4    0.599455  0.752740  0.915123
# ..        ...       ...       ...
# 329  0.472912  0.348511  0.193227
# 330  0.536868  0.231258  0.125143
# 331  0.916344  0.001173  0.369801
# 332  0.200755  0.790672  0.959268
# 333  0.445882  0.375473  0.663276
#
# [334 rows x 3 columns]

# %%
newdf.drop([0,1], axis=0, inplace=True)

# %%
newdf
# Out:
#             A         D         E
# 2    0.680728  0.557151  0.408557
# 3    0.393464  0.748520  0.662080
# 4    0.599455  0.752740  0.915123
# 5    0.543507  0.366458  0.286330
# 6    0.719936  0.125992  0.753378
# ..        ...       ...       ...
# 329  0.472912  0.348511  0.193227
# 330  0.536868  0.231258  0.125143
# 331  0.916344  0.001173  0.369801
# 332  0.200755  0.790672  0.959268
# 333  0.445882  0.375473  0.663276
#
# [332 rows x 3 columns]

# %%
# to reset rows order 0 to 
newdf.reset_index()
# Out:
#      index         A         D         E
# 0        2  0.680728  0.557151  0.408557
# 1        3  0.393464  0.748520  0.662080
# 2        4  0.599455  0.752740  0.915123
# 3        5  0.543507  0.366458  0.286330
# 4        6  0.719936  0.125992  0.753378
# ..     ...       ...       ...       ...
# 327    329  0.472912  0.348511  0.193227
# 328    330  0.536868  0.231258  0.125143
# 329    331  0.916344  0.001173  0.369801
# 330    332  0.200755  0.790672  0.959268
# 331    333  0.445882  0.375473  0.663276
#
# [332 rows x 4 columns]

# %%
# to drop old index
newdf.reset_index(drop=True)
# Out:
#             A         D         E
# 0    0.680728  0.557151  0.408557
# 1    0.393464  0.748520  0.662080
# 2    0.599455  0.752740  0.915123
# 3    0.543507  0.366458  0.286330
# 4    0.719936  0.125992  0.753378
# ..        ...       ...       ...
# 327  0.472912  0.348511  0.193227
# 328  0.536868  0.231258  0.125143
# 329  0.916344  0.001173  0.369801
# 330  0.200755  0.790672  0.959268
# 331  0.445882  0.375473  0.663276
#
# [332 rows x 3 columns]

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf
# Out:
#             A         D         E
# 0    0.680728  0.557151  0.408557
# 1    0.393464  0.748520  0.662080
# 2    0.599455  0.752740  0.915123
# 3    0.543507  0.366458  0.286330
# 4    0.719936  0.125992  0.753378
# ..        ...       ...       ...
# 327  0.472912  0.348511  0.193227
# 328  0.536868  0.231258  0.125143
# 329  0.916344  0.001173  0.369801
# 330  0.200755  0.790672  0.959268
# 331  0.445882  0.375473  0.663276
#
# [332 rows x 3 columns]

# %%
newdf['D'] = None

# %%
newdf
# Out:
#             A     D         E
# 0    0.680728  None  0.408557
# 1    0.393464  None  0.662080
# 2    0.599455  None  0.915123
# 3    0.543507  None  0.286330
# 4    0.719936  None  0.753378
# ..        ...   ...       ...
# 327  0.472912  None  0.193227
# 328  0.536868  None  0.125143
# 329  0.916344  None  0.369801
# 330  0.200755  None  0.959268
# 331  0.445882  None  0.663276
#
# [332 rows x 3 columns]

# %%
newdf['B','D'] = None

# %%
newdf
# Out:
#             A     D         E (B, D)
# 0    0.680728  None  0.408557   None
# 1    0.393464  None  0.662080   None
# 2    0.599455  None  0.915123   None
# 3    0.543507  None  0.286330   None
# 4    0.719936  None  0.753378   None
# ..        ...   ...       ...    ...
# 327  0.472912  None  0.193227   None
# 328  0.536868  None  0.125143   None
# 329  0.916344  None  0.369801   None
# 330  0.200755  None  0.959268   None
# 331  0.445882  None  0.663276   None
#
# [332 rows x 4 columns]

# %%
# to add all values in column A as 56
newdf.loc[:, ['B']] = 56

# %%
newdf.head()
# Out:
#           A     D         E (B, D)   B
# 0  0.680728  None  0.408557   None  56
# 1  0.393464  None  0.662080   None  56
# 2  0.599455  None  0.915123   None  56
# 3  0.543507  None  0.286330   None  56
# 4  0.719936  None  0.753378   None  56

# %%
df =pd.DataFrame({"name":['pl','sd','rt','pl'],
                 "toy":[np.nan,'Natmi','errt',np.nan],
                 "born":[pd.NaT,pd.Timestamp("1940-04-25"),pd.NaT,pd.NaT]})

# %%
df
# Out:
#   name    toy       born
# 0   pl    NaN        NaT
# 1   sd  Natmi 1940-04-25
# 2   rt   errt        NaT
# 3   pl    NaN        NaT

# %%
# to drop Na
df.dropna()
# Out:
#   name    toy       born
# 1   sd  Natmi 1940-04-25

# %%
df.dropna(how='all')
# Out:
#   name    toy       born
# 0   pl    NaN        NaT
# 1   sd  Natmi 1940-04-25
# 2   rt   errt        NaT
# 3   pl    NaN        NaT

# %%
# to change/drop the value of NA value to another value
df.dropna(how='all', axis=1)
# Out:
#   name    toy       born
# 0   pl    NaN        NaT
# 1   sd  Natmi 1940-04-25
# 2   rt   errt        NaT
# 3   pl    NaN        NaT

# %%
df.dropna( axis=1)
# Out:
#   name
# 0   pl
# 1   sd
# 2   rt
# 3   pl

# %%
df
# Out:
#   name    toy       born
# 0   pl    NaN        NaT
# 1   sd  Natmi 1940-04-25
# 2   rt   errt        NaT
# 3   pl    NaN        NaT

# %%
# to delete duplicate value
df.drop_duplicates(subset=['name'])
# Out:
#   name    toy       born
# 0   pl    NaN        NaT
# 1   sd  Natmi 1940-04-25
# 2   rt   errt        NaT

# %%
# to keep the last 
df.drop_duplicates(subset=['name'], keep='last')
# Out:
#   name    toy       born
# 1   sd  Natmi 1940-04-25
# 2   rt   errt        NaT
# 3   pl    NaN        NaT

# %%
#to delete all duplicate
df.drop_duplicates(subset=['name'], keep=False)
# Out:
#   name    toy       born
# 1   sd  Natmi 1940-04-25
# 2   rt   errt        NaT

# %%
df.shape
# Out:
# (4, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 224.0+ bytes

# %%
df.info
# Out:
# <bound method DataFrame.info of   name    toy       born
# 0   pl    NaN        NaT
# 1   sd  Natmi 1940-04-25
# 2   rt   errt        NaT
# 3   pl    NaN        NaT>

# %%
df['name'].value_counts(dropna=False)
# Out:
# pl    2
# sd    1
# rt    1
# Name: name, dtype: int64

# %%
df['name'].value_counts(dropna=True)
# Out:
# pl    2
# sd    1
# rt    1
# Name: name, dtype: int64

# %%
df['toy'].value_counts(dropna=False)
# Out:
# NaN      2
# Natmi    1
# errt     1
# Name: toy, dtype: int64

# %%
df['toy'].value_counts(dropna=True)
# Out:
# Natmi    1
# errt     1
# Name: toy, dtype: int64

# %%
df.notnull()
# Out:
#    name    toy   born
# 0  True  False  False
# 1  True   True   True
# 2  True   True  False
# 3  True  False  False

# %%
# df.mean()
# df.corr()
# df.count()
# df.max()
# df.min()
# df.median()
# df.std()

# %%
# to read excel file
import xlrd

# %%
xlrd
# Out:
# <module 'xlrd' from 'C:\\Users\\lenovo\\anaconda3\\lib\\site-packages\\xlrd\\__init__.py'>

# %%
data = pd.read_excel('D:/cars/train_speed.xlsx')

# %%
data
# Out:
#    Train No  Speed       City
# 0     32567     45     raipur
# 1     15676     34    kolkata
# 2     13567     67      delhi
# 3     15463     54  bangalore

# %%
data1 = pd.read_excel('D:/cars/train_speed.xlsx', sheet_name='Sheet2')

# %%
data1
# Out:
#      ss   rtg
# 0  dfdg  gfdg

# %%
data.iloc[0,0] = 45

# %%
data
# Out:
#    Train No  Speed       City
# 0        45     45     raipur
# 1     15676     34    kolkata
# 2     13567     67      delhi
# 3     15463     54  bangalore

# %%
#to create excel file
import openpyxl

# %%
data.to_excel('train_speed1.xlsx', sheet_name='Sheet1')
