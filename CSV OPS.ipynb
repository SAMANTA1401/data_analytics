# %%
import pandas as pd

# %%
A = pd.Series(['a','b','c'],index=[1,2,3])'Unnamed:3'

# %%
A
# Out:
# 1    a
# 2    b
# 3    c
# dtype: object

# %%
A.loc[1:2]
# Out:
# 1    a
# 2    b
# dtype: object

# %%
A.loc[1:3]
# Out:
# 1    a
# 2    b
# 3    c
# dtype: object

# %%
A.iloc[1:2]
# Out:
# 2    b
# dtype: object

# %%
A.iloc[1:3]
# Out:
# 2    b
# 3    c
# dtype: object

# %%
grades_dict = {'A':4,'B':3.5,'c':3,'D':2.5}
grades = pd.Series(grades_dict)

# %%
grades
# Out:
# A    4.0
# B    3.5
# c    3.0
# D    2.5
# dtype: float64

# %%
marks_dict = {'A':85,'B':75,'C':65,'D':55}
marks = pd.Series(marks_dict)

# %%
marks
# Out:
# A    85
# B    75
# C    65
# D    55
# dtype: int64

# %%
D = pd.DataFrame({'Marks':marks,'Grades':grades})

# %%
D
# Out:
#    Marks  Grades
# A   85.0     4.0
# B   75.0     3.5
# C   65.0     NaN
# D   55.0     2.5
# c    NaN     3.0

# %%
D.iloc[2,:]
# Out:
# Marks     65.0
# Grades     NaN
# Name: C, dtype: float64

# %%
# D.loc[2,:]

# %%
D.iloc[::-1,:]
# Out:
#    Marks  Grades
# c    NaN     3.0
# D   55.0     2.5
# C   65.0     NaN
# B   75.0     3.5
# A   85.0     4.0

# %%
A = pd.DataFrame([{'a':45,'b':23,'d':56},{'b':-3,'c':22,'d':23},{'a':23,'b':56,'c':90,'d':67}])

# %%
A
# Out:
#       a   b   d     c
# 0  45.0  23  56   NaN
# 1   NaN  -3  23  22.0
# 2  23.0  56  67  90.0

# %%
A.dropna()
# Out:
#       a   b   d     c
# 2  23.0  56  67  90.0

# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import sklearn

# %%
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('D:/datacsv/data.csv')

# %%
df.head(10)
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# 3  11/12/2020   11     12  2020     63      10             Afghanistan    AF
# 4  10/12/2020   10     12  2020    202      16             Afghanistan    AF
# 5  09/12/2020    9     12  2020    135      13             Afghanistan    AF
# 6  08/12/2020    8     12  2020    200       6             Afghanistan    AF
# 7  07/12/2020    7     12  2020    210      26             Afghanistan    AF
# 8  06/12/2020    6     12  2020    234      10             Afghanistan    AF
# 9  05/12/2020    5     12  2020    235      18             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# ...

# %%
df = pd.read_csv('D:/datacsv/data.csv')

# %%
df.drop(['countryterritoryCode','geoId'],axis=1,inplace=True)

# %%
df.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan
# 1  13/12/2020   13     12  2020    298       9             Afghanistan
# 2  12/12/2020   12     12  2020    113      11             Afghanistan
# 3  11/12/2020   11     12  2020     63      10             Afghanistan
# 4  10/12/2020   10     12  2020    202      16             Afghanistan
#
#    popData2019 continentExp  \
# 0   38041757.0         Asia
# 1   38041757.0         Asia
# 2   38041757.0         Asia
# 3   38041757.0         Asia
# 4   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# 2                                           6.868768
# 3                                           7.134266
# 4                                           6.968658

# %%
df.rename(columns={'countriesAndTerritories':'countries','continentExp':'continent'},inplace=True)

# %%
df.head()
# Out:
#       dateRep  day  month  year  cases  deaths    countries  popData2019  \
# 0  14/12/2020   14     12  2020    746       6  Afghanistan   38041757.0
# 1  13/12/2020   13     12  2020    298       9  Afghanistan   38041757.0
# 2  12/12/2020   12     12  2020    113      11  Afghanistan   38041757.0
# 3  11/12/2020   11     12  2020     63      10  Afghanistan   38041757.0
# 4  10/12/2020   10     12  2020    202      16  Afghanistan   38041757.0
#
#   continent  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0      Asia                                           9.013779
# 1      Asia                                           7.052776
# 2      Asia                                           6.868768
# 3      Asia                                           7.134266
# 4      Asia                                           6.968658

# %%
df['dateRep'] = pd.to_datetime(df['dateRep'])

# %%
df.head()
# Out:
#      dateRep  day  month  year  cases  deaths    countries  popData2019  \
# 0 2020-12-14   14     12  2020    746       6  Afghanistan   38041757.0
# 1 2020-12-13   13     12  2020    298       9  Afghanistan   38041757.0
# 2 2020-12-12   12     12  2020    113      11  Afghanistan   38041757.0
# 3 2020-11-12   11     12  2020     63      10  Afghanistan   38041757.0
# 4 2020-10-12   10     12  2020    202      16  Afghanistan   38041757.0
#
#   continent  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0      Asia                                           9.013779
# 1      Asia                                           7.052776
# 2      Asia                                           6.868768
# 3      Asia                                           7.134266
# 4      Asia                                           6.968658

# %%
df.describe()
# Out:
#                 day         month          year          cases        deaths  \
# count  61900.000000  61900.000000  61900.000000   61900.000000  61900.000000
# mean      15.628934      7.067157   2019.998918    1155.147237     26.055460
# std        8.841582      2.954776      0.032882    6779.224479    131.227055
# min        1.000000      1.000000   2019.000000   -8261.000000  -1918.000000
# 25%        8.000000      5.000000   2020.000000       0.000000      0.000000
# 50%       15.000000      7.000000   2020.000000      15.000000      0.000000
# 75%       23.000000     10.000000   2020.000000     273.000000      4.000000
# max       31.000000     12.000000   2020.000000  234633.000000   4928.000000
#
#         popData2019  \
# count  6.177700e+04
# mean   4.098770e+07
# std    1.531294e+08
# min    8.150000e+02
# 25%    1.293120e+06
# 50%    7.169456e+06
# 75%    2.851583e+07
# max    1.433784e+09
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61900 entries, 0 to 61899
# Data columns (total 10 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     61900 non-null  datetime64[ns]
#  1   day                                                         61900 non-null  int64
#  2   month                                                       61900 non-null  int64
#  3   year                                                        61900 non-null  int64
#  4   cases                                                       61900 non-null  int64
#  5   deaths                                                      61900 non-null  int64
#  6   countries                                                   61900 non-null  object
# ...

# %%
df = df.fillna('NA')

# %%
df
# Out:
#          dateRep  day  month  year  cases  deaths    countries popData2019  \
# 0     2020-12-14   14     12  2020    746       6  Afghanistan  38041757.0
# 1     2020-12-13   13     12  2020    298       9  Afghanistan  38041757.0
# 2     2020-12-12   12     12  2020    113      11  Afghanistan  38041757.0
# 3     2020-11-12   11     12  2020     63      10  Afghanistan  38041757.0
# 4     2020-10-12   10     12  2020    202      16  Afghanistan  38041757.0
# ...          ...  ...    ...   ...    ...     ...          ...         ...
# 61895 2020-03-25   25      3  2020      0       0     Zimbabwe  14645473.0
# 61896 2020-03-24   24      3  2020      0       1     Zimbabwe  14645473.0
# 61897 2020-03-23   23      3  2020      0       0     Zimbabwe  14645473.0
# 61898 2020-03-22   22      3  2020      1       0     Zimbabwe  14645473.0
# 61899 2020-03-21   21      3  2020      1       0     Zimbabwe  14645473.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61900 entries, 0 to 61899
# Data columns (total 10 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     61900 non-null  datetime64[ns]
#  1   day                                                         61900 non-null  int64
#  2   month                                                       61900 non-null  int64
#  3   year                                                        61900 non-null  int64
#  4   cases                                                       61900 non-null  int64
#  5   deaths                                                      61900 non-null  int64
#  6   countries                                                   61900 non-null  object
# ...

# %%
df.head(10)
# Out:
#      dateRep  day  month  year  cases  deaths    countries popData2019  \
# 0 2020-12-14   14     12  2020    746       6  Afghanistan  38041757.0
# 1 2020-12-13   13     12  2020    298       9  Afghanistan  38041757.0
# 2 2020-12-12   12     12  2020    113      11  Afghanistan  38041757.0
# 3 2020-11-12   11     12  2020     63      10  Afghanistan  38041757.0
# 4 2020-10-12   10     12  2020    202      16  Afghanistan  38041757.0
# 5 2020-09-12    9     12  2020    135      13  Afghanistan  38041757.0
# 6 2020-08-12    8     12  2020    200       6  Afghanistan  38041757.0
# 7 2020-07-12    7     12  2020    210      26  Afghanistan  38041757.0
# 8 2020-06-12    6     12  2020    234      10  Afghanistan  38041757.0
# 9 2020-05-12    5     12  2020    235      18  Afghanistan  38041757.0
#
#   continent Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0      Asia                                           9.013779
# ...

# %%
df2 = df.groupby('countries')[['countries','cases','deaths']].sum().reset_index()

# %%
df2
# Out:
#              countries  cases  deaths
# 0          Afghanistan  49273    1971
# 1              Albania  48530    1003
# 2              Algeria  92102    2596
# 3              Andorra   7338      79
# 4               Angola  16188     371
# ..                 ...    ...     ...
# 209  Wallis_and_Futuna      3       0
# 210     Western_Sahara    766       1
# 211              Yemen   2083     606
# 212             Zambia  18274     367
# 213           Zimbabwe  11246     307
#
# [214 rows x 3 columns]

# %%
df2 = df.groupby(['countries','dateRep'])[['countries','dateRep','cases','deaths']].sum().reset_index()

# %%
df2
# Out:
#          countries    dateRep  cases  deaths
# 0      Afghanistan 2019-12-31      0       0
# 1      Afghanistan 2020-01-01      0       0
# 2      Afghanistan 2020-01-02      0       0
# 3      Afghanistan 2020-01-03      0       0
# 4      Afghanistan 2020-01-04     25       0
# ...            ...        ...    ...     ...
# 61895     Zimbabwe 2020-12-10      1       0
# 61896     Zimbabwe 2020-12-11     57       0
# 61897     Zimbabwe 2020-12-12     81       1
# 61898     Zimbabwe 2020-12-13     57       1
# 61899     Zimbabwe 2020-12-14     27       0
#
# [61900 rows x 4 columns]

# %%
df3 = df2[df2['cases']>100]

# %%
df3
# Out:
#          countries    dateRep  cases  deaths
# 5      Afghanistan 2020-01-05    222       4
# 6      Afghanistan 2020-01-06    680       8
# 7      Afghanistan 2020-01-07    279      13
# 8      Afghanistan 2020-01-08    168      12
# 12     Afghanistan 2020-01-12    272      11
# ...            ...        ...    ...     ...
# 61875     Zimbabwe 2020-11-17    111       0
# 61884     Zimbabwe 2020-11-26    110       0
# 61885     Zimbabwe 2020-11-27    115       0
# 61887     Zimbabwe 2020-11-29    108       0
# 61888     Zimbabwe 2020-11-30    128       1
#
# [20917 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10,1000)
y = np.sin(x)
plt.plot(x,y)

# %%
plt.scatter(x[::10],y[::10],color='red')

# %%
plt.plot(x,y,color='b')
plt.plot(x,np.cos(x),color='r')
