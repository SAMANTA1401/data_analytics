# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(color_codes=True)

# %%
# importing panda library
import pandas as pd

# readinag given csv file
# and creating dataframe
df1 = pd.read_csv("D:/cars/cars.txt")

# %%
df1
# Out:
#     YEAR        Make                            Model                   Size  \
# 0   2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 1   2012      NISSAN                             LEAF               MID-SIZE
# 2   2013        FORD                   FOCUS ELECTRIC                COMPACT
# 3   2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 4   2013      NISSAN                             LEAF               MID-SIZE
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 7   2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 8   2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# ...

# %%
# storing this dataframe in a csv file
df1.to_csv('D:/cars/cars.csv',index = None)

# %%
df1
# Out:
#     YEAR        Make                            Model                   Size  \
# 0   2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 1   2012      NISSAN                             LEAF               MID-SIZE
# 2   2013        FORD                   FOCUS ELECTRIC                COMPACT
# 3   2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 4   2013      NISSAN                             LEAF               MID-SIZE
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 7   2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 8   2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# ...

# %%
df1.dtypes
# Out:
# YEAR                   int64
# Make                  object
# Model                 object
# Size                  object
# (kW)                   int64
# Unnamed: 5            object
# TYPE                  object
# CITY (kWh/100 km)    float64
# HWY (kWh/100 km)     float64
# COMB (kWh/100 km)    float64
# CITY (Le/100 km)     float64
# HWY (Le/100 km)      float64
# COMB (Le/100 km)     float64
# (g/km)                 int64
# RATING               float64
# (km)                   int64
# TIME (h)               int64
# dtype: object

# %%
df1.columns
# Out:
# Index(['YEAR', 'Make', 'Model', 'Size', '(kW)', 'Unnamed: 5', 'TYPE',
#        'CITY (kWh/100 km)', 'HWY (kWh/100 km)', 'COMB (kWh/100 km)',
#        'CITY (Le/100 km)', 'HWY (Le/100 km)', 'COMB (Le/100 km)', '(g/km)',
#        'RATING', '(km)', 'TIME (h)'],
#       dtype='object')

# %%
df1.describe()
# Out:
#               YEAR        (kW)  CITY (kWh/100 km)  HWY (kWh/100 km)  \
# count    53.000000   53.000000           53.00000         53.000000
# mean   2014.735849  190.622642           19.64717         21.633962
# std       1.227113  155.526429            3.00100          1.245753
# min    2012.000000   35.000000           15.20000         18.800000
# 25%    2014.000000   80.000000           17.00000         20.800000
# 50%    2015.000000  107.000000           19.00000         21.700000
# 75%    2016.000000  283.000000           22.40000         22.500000
# max    2016.000000  568.000000           23.90000         23.300000
#
#        COMB (kWh/100 km)  CITY (Le/100 km)  HWY (Le/100 km)  COMB (Le/100 km)  \
# count          53.000000         53.000000        53.000000         53.000000
# mean           20.541509          2.207547         2.422642          2.301887
# std             1.979455          0.344656         0.143636          0.212576
# ...

# %%
# df1.hist(figsize=(20,30))

# %%
sns.boxplot(x="Size",y="(kW)", data=df1)
# Out:
# <AxesSubplot:xlabel='Size', ylabel='(kW)'>

# %%
# sns.pairplot(df1)

# %%
df1.rename(columns={'Unnamed: 5':'countries','CITY (Le/100 km)':'continent','HWY (Le/100 km)':'a','COMB (Le/100 km)':'b'},inplace=True)

# %%
df1.head()
# Out:
#    YEAR        Make           Model        Size  (kW) countries TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49        A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80        A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107        A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49        A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80        A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  continent    a  \
# 0               16.9              21.4               18.7        1.9  2.4
# 1               19.3              23.0               21.1        2.2  2.6
# 2               19.0              21.1               20.0        2.1  2.4
# 3               16.9              21.4               18.7        1.9  2.4
# 4               19.3              23.0               21.1        2.2  2.6
#
#      b  (g/km)  RATING  (km)  TIME (h)
# 0  2.1       0     NaN   100         7
# ...

# %%
df1.drop(['countries','continent','a','b'],axis=1,inplace=True)

# %%
# df1

# %%
df1.shape
# Out:
# (53, 13)

# %%
duplicate_rows_car = df1[df1.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_car.shape)
# Out:
# Number of duplicate rows:  (0, 13)

# %%
df1.count()
# Out:
# YEAR                 53
# Make                 53
# Model                53
# Size                 53
# (kW)                 53
# TYPE                 53
# CITY (kWh/100 km)    53
# HWY (kWh/100 km)     53
# COMB (kWh/100 km)    53
# (g/km)               53
# RATING               19
# (km)                 53
# TIME (h)             53
# dtype: int64

# %%
df1 = df1.drop_duplicates()
df1.head()
# Out:
#    YEAR        Make           Model        Size  (kW) TYPE  CITY (kWh/100 km)  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49    B               16.9
# 1  2012      NISSAN            LEAF    MID-SIZE    80    B               19.3
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107    B               19.0
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49    B               16.9
# 4  2013      NISSAN            LEAF    MID-SIZE    80    B               19.3
#
#    HWY (kWh/100 km)  COMB (kWh/100 km)  (g/km)  RATING  (km)  TIME (h)
# 0              21.4               18.7       0     NaN   100         7
# 1              23.0               21.1       0     NaN   117         7
# 2              21.1               20.0       0     NaN   122         4
# 3              21.4               18.7       0     NaN   100         7
# 4              23.0               21.1       0     NaN   117         7

# %%
df1.count()
# Out:
# YEAR                 53
# Make                 53
# Model                53
# Size                 53
# (kW)                 53
# TYPE                 53
# CITY (kWh/100 km)    53
# HWY (kWh/100 km)     53
# COMB (kWh/100 km)    53
# (g/km)               53
# RATING               19
# (km)                 53
# TIME (h)             53
# dtype: int64

# %%
print(df1.isnull().sum())
# Out:
# YEAR                  0
# Make                  0
# Model                 0
# Size                  0
# (kW)                  0
# TYPE                  0
# CITY (kWh/100 km)     0
# HWY (kWh/100 km)      0
# COMB (kWh/100 km)     0
# (g/km)                0
# RATING               34
# (km)                  0
# TIME (h)              0
# dtype: int64

# %%
df1 = df1.dropna(axis = 1)

# %%
df1
# Out:
#     YEAR        Make                            Model                   Size  \
# 0   2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 1   2012      NISSAN                             LEAF               MID-SIZE
# 2   2013        FORD                   FOCUS ELECTRIC                COMPACT
# 3   2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 4   2013      NISSAN                             LEAF               MID-SIZE
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 7   2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 8   2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# ...

# %%
df1.count()
# Out:
# YEAR                 53
# Make                 53
# Model                53
# Size                 53
# (kW)                 53
# TYPE                 53
# CITY (kWh/100 km)    53
# HWY (kWh/100 km)     53
# COMB (kWh/100 km)    53
# (g/km)               53
# (km)                 53
# TIME (h)             53
# dtype: int64

# %%
print(df1.isnull().sum())
# Out:
# YEAR                 0
# Make                 0
# Model                0
# Size                 0
# (kW)                 0
# TYPE                 0
# CITY (kWh/100 km)    0
# HWY (kWh/100 km)     0
# COMB (kWh/100 km)    0
# (g/km)               0
# (km)                 0
# TIME (h)             0
# dtype: int64

# %%
sns.boxplot(x=df1['(kW)'])
# Out:
# <AxesSubplot:xlabel='(kW)'>

# %%
df1.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("number of cars by make")
plt.ylabel("number of cars")
plt.xlabel("Make")
# Out:
# Text(0.5, 0, 'Make')

# %%
plt.figure(figsize=(20,10))
c=df1.corr()

c
# Out:
#                        YEAR      (kW)  CITY (kWh/100 km)  HWY (kWh/100 km)  \
# YEAR               1.000000  0.303071           0.046792         -0.264488
# (kW)               0.303071  1.000000           0.827555          0.046083
# CITY (kWh/100 km)  0.046792  0.827555           1.000000          0.442151
# HWY (kWh/100 km)  -0.264488  0.046083           0.442151          1.000000
# COMB (kWh/100 km) -0.034193  0.706847           0.965258          0.657155
# (g/km)                  NaN       NaN                NaN               NaN
# (km)               0.234407  0.894615           0.906960          0.166217
# TIME (h)           0.139391  0.757326           0.806459          0.316639
#
#                    COMB (kWh/100 km)  (g/km)      (km)  TIME (h)
# YEAR                       -0.034193     NaN  0.234407  0.139391
# (kW)                        0.706847     NaN  0.894615  0.757326
# CITY (kWh/100 km)           0.965258     NaN  0.906960  0.806459
# ...

# %%
 sns.heatmap(c,cmap="BrBG", annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(c,cmap="coolwarm", annot=True)
# Out:
# <AxesSubplot:>
