# %%
import pandas as pd

# %%
df = pd.read_csv('data_nse.csv')

# %%
df
# Out:
#           SYMBOL SERIES         DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 0      20MICRONS     EQ   13-Apr-2022       90.30       90.70       92.40
# 1     21STCENMGM     EQ   13-Apr-2022       30.55       30.90       30.95
# 2      3IINFOLTD     EQ   13-Apr-2022       66.40       68.00       68.50
# 3        3MINDIA     EQ   13-Apr-2022    21378.40    21232.00    21400.00
# 4         3PLAND     EQ   13-Apr-2022       19.40       19.80       20.45
# ...          ...    ...           ...         ...         ...         ...
# 2200        ZOTA     EQ   13-Apr-2022      325.50      324.10      348.70
# 2201       ZUARI     EQ   13-Apr-2022      177.45      181.00      186.10
# 2202   ZUARIGLOB     EQ   13-Apr-2022      192.05      194.85      198.40
# 2203   ZYDUSLIFE     EQ   13-Apr-2022      363.35      365.00      369.35
# 2204   ZYDUSWELL     EQ   13-Apr-2022     1654.35     1662.65     1693.85
#
#       LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  \
# ...

# %%
print(df['SYMBOL'].dtype)
# Out:
# object

# %%
print(df['PREV_CLOSE'])
# Out:
# 0          90.30
# 1          30.55
# 2          66.40
# 3       21378.40
# 4          19.40
#           ...
# 2200      325.50
# 2201      177.45
# 2202      192.05
# 2203      363.35
# 2204     1654.35
# Name: PREV_CLOSE, Length: 2205, dtype: float64
